# %% [markdown]
# ### Coleta de dados

# %%
import linkedin_scraper as scraper

df = scraper.get_vagas("data scientist", "Brasil", 60)
df.to_csv("Dados_LinkedIn.csv", index = False)
display(df)
# Out:
#                                         Titulo da vaga  \
# 0                                         Data Modeler
# 1                                  Lead Data Scientist
# 2                                 Analista de software
# 3    Lead Data Scientist (Bangkok based, relocation...
# 4                                Senior Data Scientist
# ..                                                 ...
# 714        Desenvolvedor Java Júnior (351087) - REMOTE
# 715                     Salesforce Data Cloud Engineer
# 716                             Engenheiro de Dados Pl
# 717    Desenvolvedor ou Desenvolvedora Apex Salesforce
# 718                      Desenvolvedor(a) Java - Pleno
#
#                                        Detalhe da vaga  \
# 0    [Greymatter Innovationz, São Paulo, Brasil, há...
# 1    [ADP Brazil Labs, Porto Alegre, Rio Grande do ...
# 2    [Formel D Group, Brasil, há 4 minutos, 3 candi...
# 3    [Agoda, Rio de Janeiro, Rio de Janeiro, Brasil...
# ...
